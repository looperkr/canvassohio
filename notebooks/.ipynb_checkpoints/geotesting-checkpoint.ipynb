# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import feather
import os

# %%
import geopy

# %%
# %matplotlib inline

# %%
df = feather.read_dataframe('/Volumes/FileStorage/Insight_data/Ohio_data/data_feather/subset_oh.feather')

# %%
df.head()
# Out:
#     SOS_VOTERID  COUNTY_NUMBER  COUNTY_ID  LAST_NAME FIRST_NAME MIDDLE_NAME  \
# 0  OH0019419095              6      40055    KITCHEN     LESLIE           L
# 1  OH0019489283              9     482703      GRACE     AMANDA       LEIGH
# 2  OH0015384921             18    2044314     CARNER    TIFFANY           J
# 3  OH0020115764             13    6100757  VAN SCYOC      SUSAN           L
# 4  OH0015058130             18    1674659      BERRY     NICOLE           L
#
#   SUFFIX DATE_OF_BIRTH REGISTRATION_DATE VOTER_STATUS  ... GENERAL-06/07/2016  \
# 0   None    1969-12-26        2008-01-09       ACTIVE  ...               None
# 1   None    1974-11-09        2008-02-01       ACTIVE  ...               None
# 2   None    1971-08-28        2016-05-25       ACTIVE  ...               None
# 3   None    1973-08-01        2008-09-18       ACTIVE  ...               None
# 4   None    1975-04-25        2009-08-19       ACTIVE  ...               None
#
# ...

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="canvassohio")

# %%
location = geolocator.geocode("420 E. Chapin St. Morris IL")

# %%
print(location.address)
# Out:
# 420, East Chapin Street, Morris, Grundy County, Illinois, 60450, United States of America

# %%
print((location.latitude, location.longitude))
# Out:
# (41.3620815102041, -88.4196454897959)

# %%
df.loc[:,'RESIDENTIAL_ADDRESS1':'RESIDENTIAL_ZIP'].head()
# Out:
#    RESIDENTIAL_ADDRESS1 RESIDENTIAL_SECONDARY_ADDR RESIDENTIAL_CITY  \
# 0       122 CONCORD AVE                       None         ST MARYS
# 1  932 SLEEPY HOLLOW DR                       None           MONROE
# 2     13902 BENWOOD AVE                       None        CLEVELAND
# 3     1090 S MUSCOVY DR                       None         LOVELAND
# 4      16308 KOLLIN AVE                       None        CLEVELAND
#
#   RESIDENTIAL_STATE  RESIDENTIAL_ZIP
# 0                OH            45885
# 1                OH            45050
# 2                OH            44105
# 3                OH            45140
# 4                OH            44128

# %%
df['test']=df['RESIDENTIAL_ADDRESS1']+' '+df['RESIDENTIAL_CITY']+' '+df['RESIDENTIAL_STATE']+' '+df['RESIDENTIAL_ZIP'].map(str)

# %%
df.head()
# Out:
#     SOS_VOTERID  COUNTY_NUMBER  COUNTY_ID  LAST_NAME FIRST_NAME MIDDLE_NAME  \
# 0  OH0019419095              6      40055    KITCHEN     LESLIE           L
# 1  OH0019489283              9     482703      GRACE     AMANDA       LEIGH
# 2  OH0015384921             18    2044314     CARNER    TIFFANY           J
# 3  OH0020115764             13    6100757  VAN SCYOC      SUSAN           L
# 4  OH0015058130             18    1674659      BERRY     NICOLE           L
#
#   SUFFIX DATE_OF_BIRTH REGISTRATION_DATE VOTER_STATUS  ... PRIMARY-09/13/2016  \
# 0   None    1969-12-26        2008-01-09       ACTIVE  ...               None
# 1   None    1974-11-09        2008-02-01       ACTIVE  ...               None
# 2   None    1971-08-28        2016-05-25       ACTIVE  ...               None
# 3   None    1973-08-01        2008-09-18       ACTIVE  ...               None
# 4   None    1975-04-25        2009-08-19       ACTIVE  ...               None
#
# ...

# %%
df['test'].head()
# Out:
# 0       122 CONCORD AVE ST MARYS OH 45885
# 1    932 SLEEPY HOLLOW DR MONROE OH 45050
# 2    13902 BENWOOD AVE CLEVELAND OH 44105
# 3     1090 S MUSCOVY DR LOVELAND OH 45140
# 4     16308 KOLLIN AVE CLEVELAND OH 44128
# Name: test, dtype: object

# %%
df.iloc[0]['test']
# Out:
# '122 CONCORD AVE ST MARYS OH 45885'

# %%
location = geolocator.geocode("420 E CHAPIN ST MORRIS IL 60450")

# %%
print(location)
# Out:
# 420, East Chapin Street, Morris, Grundy County, Illinois, 60450, United States of America

# %%
test_df=df['RESIDENTIAL_ADDRESS1']+' '+df['RESIDENTIAL_CITY']+' '+df['RESIDENTIAL_STATE']+' '+df['RESIDENTIAL_ZIP'].map(str)

# %%
print(test_df.head())
# Out:
# 0       122 CONCORD AVE ST MARYS OH 45885
# 1    932 SLEEPY HOLLOW DR MONROE OH 45050
# 2    13902 BENWOOD AVE CLEVELAND OH 44105
# 3     1090 S MUSCOVY DR LOVELAND OH 45140
# 4     16308 KOLLIN AVE CLEVELAND OH 44128
# dtype: object

# %%
test_df.shape
# Out:
# (150,)

# %%
test_df.drop_duplicates(keep='first',inplace=True)

# %%
test_df.shape
# Out:
# (150,)

# %%
df.loc[:,'RESIDENTIAL_ADDRESS1':'RESIDENTIAL_ZIP'].head()
# Out:
#    RESIDENTIAL_ADDRESS1 RESIDENTIAL_SECONDARY_ADDR RESIDENTIAL_CITY  \
# 0       122 CONCORD AVE                       None         ST MARYS
# 1  932 SLEEPY HOLLOW DR                       None           MONROE
# 2     13902 BENWOOD AVE                       None        CLEVELAND
# 3     1090 S MUSCOVY DR                       None         LOVELAND
# 4      16308 KOLLIN AVE                       None        CLEVELAND
#
#   RESIDENTIAL_STATE  RESIDENTIAL_ZIP
# 0                OH            45885
# 1                OH            45050
# 2                OH            44105
# 3                OH            45140
# 4                OH            44128

# %%
new_df=df.loc[:,'RESIDENTIAL_ADDRESS1':'RESIDENTIAL_ZIP']

# %%
new_df.drop(columns=['RESIDENTIAL_SECONDARY_ADDR'])
# Out:
#                 RESIDENTIAL_ADDRESS1 RESIDENTIAL_CITY RESIDENTIAL_STATE  \
# 0                    122 CONCORD AVE         ST MARYS                OH
# 1               932 SLEEPY HOLLOW DR           MONROE                OH
# 2                  13902 BENWOOD AVE        CLEVELAND                OH
# 3                  1090 S MUSCOVY DR         LOVELAND                OH
# 4                   16308 KOLLIN AVE        CLEVELAND                OH
# 5                 3419 E OXFORD OVAL    NORTH OLMSTED                OH
# 6                   6137 TAYLOR PIKE      BLANCHESTER                OH
# 7                   6787 LINDSLEY AV          ANDOVER                OH
# 8                6321 TRAIL RIDGE CT         LOVELAND                OH
# 9                 25 PEPPER CREEK DR      PEPPER PIKE                OH
# 10                    1916 W 50TH ST        CLEVELAND                OH
# 11   55505 BLOOMINGDALE ST WOLFHURST       BRIDGEPORT                OH
# ...

# %%
new_df.head()
# Out:
#    RESIDENTIAL_ADDRESS1 RESIDENTIAL_SECONDARY_ADDR RESIDENTIAL_CITY  \
# 0       122 CONCORD AVE                       None         ST MARYS
# 1  932 SLEEPY HOLLOW DR                       None           MONROE
# 2     13902 BENWOOD AVE                       None        CLEVELAND
# 3     1090 S MUSCOVY DR                       None         LOVELAND
# 4      16308 KOLLIN AVE                       None        CLEVELAND
#
#   RESIDENTIAL_STATE  RESIDENTIAL_ZIP
# 0                OH            45885
# 1                OH            45050
# 2                OH            44105
# 3                OH            45140
# 4                OH            44128

# %%
df.drop_duplicates(subset=['RESIDENTIAL_ADDRESS1','RESIDENTIAL_CITY','RESIDENTIAL_STATE','RESIDENTIAL_ZIP']).head()
# Out:
#     SOS_VOTERID  COUNTY_NUMBER  COUNTY_ID  LAST_NAME FIRST_NAME MIDDLE_NAME  \
# 0  OH0019419095              6      40055    KITCHEN     LESLIE           L
# 1  OH0019489283              9     482703      GRACE     AMANDA       LEIGH
# 2  OH0015384921             18    2044314     CARNER    TIFFANY           J
# 3  OH0020115764             13    6100757  VAN SCYOC      SUSAN           L
# 4  OH0015058130             18    1674659      BERRY     NICOLE           L
#
#   SUFFIX DATE_OF_BIRTH REGISTRATION_DATE VOTER_STATUS  ... PRIMARY-09/13/2016  \
# 0   None    1969-12-26        2008-01-09       ACTIVE  ...               None
# 1   None    1974-11-09        2008-02-01       ACTIVE  ...               None
# 2   None    1971-08-28        2016-05-25       ACTIVE  ...               None
# 3   None    1973-08-01        2008-09-18       ACTIVE  ...               None
# 4   None    1975-04-25        2009-08-19       ACTIVE  ...               None
#
# ...

# %%
len(df.index)
# Out:
# 150

# %%
t_name = 'addr_slice'

# %%
t_name[:10]
# Out:
# 'addr_slice'

# %%
tcsv = 'test.csv'

# %%
tcsv.split('.')[0]+'_output.csv'
# Out:
# 'test_output.csv'

# %%
fp = "/Volumes/FileStorage/Insight_data/cb_2018_39_sldl_500k/cb_2018_39_sldl_500k.shp"

# %%
import geopandas as gpd

# %%
map_df = gpd.read_file(fp)

# %%
map_df.head()
# Out:
#   STATEFP SLDLST        AFFGEOID  GEOID NAME LSAD   LSY       ALAND    AWATER  \
# 0      39    090  620L600US39090  39090   90   LL  2018  3136392398  23894013
# 1      39    020  620L600US39020  39020   20   LL  2018   232051950   4630483
# 2      39    049  620L600US39049  39049   49   LL  2018   331595304    861234
# 3      39    091  620L600US39091  39091   91   LL  2018  3876243149  32373189
# 4      39    070  620L600US39070  39070   70   LL  2018  1836917895  12310066
#
#                                             geometry
# 0  POLYGON ((-83.7053136208764 38.6397614234931, ...
# 1  POLYGON ((-83.016471 39.811442, -83.0075049999...
# 2  POLYGON ((-81.559315 40.777532, -81.559119 40....
# 3  POLYGON ((-84.003728 39.288471, -84.003699 39....
# 4  POLYGON ((-82.436916 41.065379, -82.424905 41....

# %%
map_df.plot()

# %%
import io

# %%
map_plt=io.BytesIO()

# %%
plt.savefig(map_plt, format='png')
