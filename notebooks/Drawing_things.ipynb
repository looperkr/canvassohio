# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import io
import geopandas as gpd
from matplotlib.figure import Figure
import pickle

# %%
def draw_map():
    fp = "/Volumes/FileStorage/Insight_data/cb_2018_39_sldl_500k/cb_2018_39_sldl_500k.shp"
    fig = Figure()
    map_df = gpd.read_file(fp)
    map_df.plot(color='white', edgecolor='black',figsize=(12, 12))
    return fig

# %%
# %matplotlib inline

# %%
results_dict='/Users/kristinalooper/WorkArea/insight/canvassohio/canvassohio/static/precinct_dict.pickle'
with open(results_dict, 'rb') as handle:
    districts_dic = pickle.load(handle)
    districts=districts_dic.items()

# %%
draw_map()
plt.axis('equal')
#plt.savefig('/Users/kristinalooper/WorkArea/insight/canvassohio/canvassohio/static/ohio_map.png')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /Volumes/FileStorage/Insight_data/cb_2018_39_sldl_500k/cb_2018_39_sldl_500k.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-10-fee642496de3> in <module>
# ----> 1 draw_map()
#       2 plt.axis('equal')
#       3 #plt.savefig('/Users/kristinalooper/WorkArea/insight/canvassohio/canvassohio/static/ohio_map.png')
#
# <ipython-input-6-4591478fe8d0> in draw_map()
#       2     fp = "/Volumes/FileStorage/Insight_data/cb_2018_39_sldl_500k/cb_2018_39_sldl_500k.shp"
#       3     fig = Figure()
# ----> 4     map_df = gpd.read_file(fp)
#       5     map_df.plot(color='white', edgecolor='black',figsize=(12, 12))
#       6     return fig
#
# /usr/local/lib/python3.7/site-packages/geopandas/io/file.py in read_file(filename, bbox, **kwargs)
#      75
#      76     with fiona_env():
# ---> 77         with reader(path_or_bytes, **kwargs) as features:
#      78
#      79             # In a future Fiona release the crs attribute of features will
#
# /usr/local/lib/python3.7/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     395     def wrapper(*args, **kwargs):
#     396         if local._env:
# --> 397             return f(*args, **kwargs)
#     398         else:
#     399             if isinstance(args[0], str):
#
# /usr/local/lib/python3.7/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     251         if mode in ('a', 'r'):
#     252             c = Collection(path, mode, driver=driver, encoding=encoding,
# --> 253                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     254         elif mode == 'w':
#     255             if schema:
#
# /usr/local/lib/python3.7/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     157             if self.mode == 'r':
#     158                 self.session = Session()
# --> 159                 self.session.start(self, **kwargs)
#     160             elif self.mode in ('a', 'w'):
#     161                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: /Volumes/FileStorage/Insight_data/cb_2018_39_sldl_500k/cb_2018_39_sldl_500k.shp: No such file or directory

# %%
fp = "/Volumes/FileStorage/Insight_data/cb_2018_39_sldl_500k/cb_2018_39_sldl_500k.shp"
fig = Figure()
map_df = gpd.read_file(fp)

# %%
map_df.crs
# Out:
# {'init': 'epsg:4269'}

# %%
test_df=map_df[map_df.NAME=='1']

# %%
test_df.plot()

# %%
static_dir='/Users/kristinalooper/WorkArea/insight/canvassohio/canvassohio/static/'

# %%
for i in range(1,100):
    img_name=static_dir+'district_'+str(i)+'.png'
    d_df=map_df[map_df.NAME==str(i)]
    d_df.plot(color='grey', edgecolor='black',figsize=(12, 12))
    plt.axis('off')
    plt.axis('equal')
    plt.savefig(img_name)
    plt.close()

# %%
def draw_precinct():
    fp = "/Volumes/FileStorage/Insight_data/shp/precincts_results.shp"
    fig = Figure()
    map_df = gpd.read_file(fp)
    map_df.plot(color='white', edgecolor='black',figsize=(12, 12))
    return fig

# %%
draw_precinct()
plt.axis('equal')
# Out:
# (151095.86413011045, 559225.0243981234, 4231929.981505228, 4667176.236039725)

# %%
fp_prec = "/Volumes/FileStorage/Insight_data/shp/precincts_results.shp"
prec_df = gpd.read_file(fp_prec)
prec_df
# Out:
#            fid                PRECINCT     COUNTY  global_id  COUNTYGEOI  \
# 0          1.0       GALLIPOLIS CITY 1     gallia     4179.0     39053.0
# 1          2.0       GALLIPOLIS CITY 3     gallia     4180.0     39053.0
# 2          3.0       GALLIPOLIS CITY 2     gallia     4181.0     39053.0
# 3          4.0        ADDISON TOWNSHIP     gallia     4182.0     39053.0
# 4          5.0       CHESHIRE TOWNSHIP     gallia     4183.0     39053.0
# 5          6.0           CLAY TOWNSHIP     gallia     4184.0     39053.0
# 6          7.0     GALLIPOLIS TOWNSHIP     gallia     4185.0     39053.0
# 7          8.0        GREEN TOWNSHIP 1     gallia     4186.0     39053.0
# 8          9.0        GREEN TOWNSHIP 2     gallia     4187.0     39053.0
# 9         10.0        GREEN TOWNSHIP 4     gallia     4188.0     39053.0
# 10        11.0        GREEN TOWNSHIP 5     gallia     4189.0     39053.0
# 11        12.0     GREENFIELD TOWNSHIP     gallia     4190.0     39053.0
# 12        13.0          GUYAN PRECINCT     gallia     4191.0     39053.0
# 13        14.0          GUYAN TOWNSHIP     gallia     4192.0     39053.0
# 14        15.0       HARRISON TOWNSHIP     gallia     4193.0     39053.0
# 15        16.0     HUNTINGTON TOWNSHIP     gallia     4194.0     39053.0
# 16        17.0         MORGAN TOWNSHIP     gallia     4195.0     39053.0
# 17        18.0           OHIO TOWNSHIP     gallia     4196.0     39053.0
# 18        19.0          PERRY TOWNSHIP     gallia     4197.0     39053.0
# 19        20.0    CENTERVILLE PRECINCT     gallia     4198.0     39053.0
# 20        21.0        RACCOON TOWNSHIP     gallia     4199.0     39053.0
# 21        22.0        BIDWELL PRECINCT     gallia     4200.0     39053.0
# 22        23.0  SPRINGFIELD TOWNSHIP 1     gallia     4201.0     39053.0
# 23        24.0  SPRINGFIELD TOWNSHIP 2     gallia     4202.0     39053.0
# 24        25.0         WALNUT TOWNSHIP     gallia     4203.0     39053.0
# 25        26.0                    VI-A  fairfield     4504.0     39045.0
# 26        27.0                    VI-A  fairfield     4507.0     39045.0
# 27        28.0                    VI-A  fairfield     4601.0     39045.0
# 28        29.0                    VI-O  fairfield     4505.0     39045.0
# 29        30.0                    VI-E  fairfield     4506.0     39045.0
# ...        ...                     ...        ...        ...         ...
# 10562  10563.0                    None   franklin        NaN         NaN
# 10563  10564.0                    None   franklin        NaN         NaN
# 10564  10565.0                    None   franklin        NaN         NaN
# 10565  10566.0                    None   franklin        NaN         NaN
# 10566  10567.0                    None   franklin        NaN         NaN
# 10567  10568.0                    None   franklin        NaN         NaN
# 10568  10569.0                    None   franklin        NaN         NaN
# 10569  10570.0                    None      henry        NaN         NaN
# 10570  10571.0                    None       knox        NaN         NaN
# 10571  10572.0                    None       lake        NaN         NaN
# 10572  10573.0                    None   mahoning        NaN         NaN
# 10573  10574.0                    None     monroe        NaN         NaN
# 10574  10575.0                    None      perry        NaN         NaN
# 10575  10576.0                    None   pickaway        NaN         NaN
# 10576  10577.0                    None   pickaway        NaN         NaN
# 10577  10578.0                    None   pickaway        NaN         NaN
# 10578  10579.0                    None   pickaway        NaN         NaN
# 10579  10580.0                    None   pickaway        NaN         NaN
# 10580  10581.0                    None   pickaway        NaN         NaN
# 10581  10582.0                    None   pickaway        NaN         NaN
# 10582  10583.0                    None   pickaway        NaN         NaN
# 10583  10584.0                    None   pickaway        NaN         NaN
# 10584  10585.0                    None   pickaway        NaN         NaN
# 10585  10586.0                    None    portage        NaN         NaN
# 10586  10587.0                    None    portage        NaN         NaN
# 10587  10588.0                    None   sandusky        NaN         NaN
# 10588  10589.0                    None     scioto        NaN         NaN
# 10589  10590.0                    None     scioto        NaN         NaN
# 10590  10591.0                    None     scioto        NaN         NaN
# 10591  10592.0                    None       wood        NaN         NaN
#
#                               PRECINCT_e PRECINCTCO PRECINCT_m county_nam  \
# 0                      GALLIPOLIS CITY 1        AAA       None     Gallia
# 1                      GALLIPOLIS CITY 3        AAB       None     Gallia
# 2                      GALLIPOLIS CITY 2        AAE       None     Gallia
# 3                            ADDISON TWP        AAG       None     Gallia
# 4                           CHESHIRE TWP        AAI       None     Gallia
# 5                               CLAY TWP        AAK       None     Gallia
# 6                         GALLIPOLIS TWP        AAL       None     Gallia
# 7                                GREEN 1        AAN       None     Gallia
# 8                                GREEN 2        AAO       None     Gallia
# 9                                GREEN 4        AAQ       None     Gallia
# 10                               GREEN 5        AAR       None     Gallia
# 11                        GREENFIELD TWP        AAT       None     Gallia
# 12                             GUYAN PCT        AAU       None     Gallia
# 13                             GUYAN TWP        AAV       None     Gallia
# 14                          HARRISON TWP        AAW       None     Gallia
# 15                        HUNTINGTON TWP        AAY       None     Gallia
# 16                            MORGAN TWP        AAZ       None     Gallia
# 17                              OHIO TWP        ABA       None     Gallia
# 18                             PERRY TWP        ABB       None     Gallia
# 19                       CENTERVILLE PCT        ABC       None     Gallia
# 20                           RACCOON TWP        ABD       None     Gallia
# 21                           BIDWELL PCT        ABF       None     Gallia
# 22                         SPRINGFIELD 1        ABG       None     Gallia
# 23                         SPRINGFIELD 2        ABH       None     Gallia
# 24                            WALNUT TWP        ABJ       None     Gallia
# 25                              VIOLET A        ADK       None  Fairfield
# 26                              VIOLET A        ADK       None  Fairfield
# 27                              VIOLET A        ADK       None  Fairfield
# 28                              VIOLET O        ADY       None  Fairfield
# 29                              VIOLET E        ADO       None  Fairfield
# ...                                  ...        ...        ...        ...
# 10562                          REYNS 2-F       None       None   Franklin
# 10563                          REYNS 3-A       None       None   Franklin
# 10564                          REYNS 3-B       None       None   Franklin
# 10565                          REYNS 4-B       None       None   Franklin
# 10566                            TRURO-A       None       None   Franklin
# 10567                          REYNS 4-F       None       None   Franklin
# 10568                          COLS 69-K       None       None   Franklin
# 10569                   LIBERTY TWP 14.0       None       None      Henry
# 10570                PRECINCT CENTERBURG       None       None       Knox
# 10571  PRECINCT WILLOUGHBY HILLS CITY GG       None       None       Lake
# 10572                     PRECINCT SBC 4       None       None   Mahoning
# 10573          PRECINCT WOODSFIELD SOUTH       None       None     Monroe
# 10574                            MCLUNEY       None       None      Perry
# 10575           PRECINCT CIRCLEVILLE 1-A       None       None   Pickaway
# 10576           PRECINCT CIRCLEVILLE 1-B       None       None   Pickaway
# 10577           PRECINCT CIRCLEVILLE 1-C       None       None   Pickaway
# 10578           PRECINCT CIRCLEVILLE 1-D       None       None   Pickaway
# 10579           PRECINCT CIRCLEVILLE 2-A       None       None   Pickaway
# 10580           PRECINCT CIRCLEVILLE 2-B       None       None   Pickaway
# 10581           PRECINCT CIRCLEVILLE 3-A       None       None   Pickaway
# 10582           PRECINCT CIRCLEVILLE 3-B       None       None   Pickaway
# 10583           PRECINCT CIRCLEVILLE 4-A       None       None   Pickaway
# 10584           PRECINCT CIRCLEVILLE 4-B       None       None   Pickaway
# 10585        PRECINCT BRADY LAKE VILLAGE       None       None    Portage
# 10586         PRECINCT SUGAR BUSH KNOLLS       None       None    Portage
# 10587                             HELENA       None       None   Sandusky
# 10588            PRECINCT PORTSMOUTH 1-A       None       None     Scioto
# 10589            PRECINCT PORTSMOUTH 1-B       None       None     Scioto
# 10590            PRECINCT PORTSMOUTH 1-C       None       None     Scioto
# 10591                  BOWLING GREEN 3-C       None       None       Wood
#
#       precinct_c  ... pres_16__3 pres_16_ev  pres_16_mo  pres_16__4  \
# 0            AAA  ...        0.0        0.0         0.0         0.0
# 1            AAB  ...        0.0        0.0         0.0         0.0
# 2            AAE  ...        0.0        0.0         0.0         0.0
# 3            AAG  ...        0.0        0.0         0.0         0.0
# 4            AAI  ...        0.0        0.0         0.0         0.0
# 5            AAK  ...        0.0        0.0         0.0         0.0
# 6            AAL  ...        0.0        0.0         0.0         0.0
# 7            AAN  ...        0.0        0.0         0.0         0.0
# 8            AAO  ...        0.0        0.0         0.0         0.0
# 9            AAQ  ...        0.0        0.0         0.0         0.0
# 10           AAR  ...        0.0        0.0         0.0         0.0
# 11           AAT  ...        0.0        0.0         0.0         0.0
# 10591         0.0        20.0         0.0         0.0       209.0
#
#                                                 geometry
# 0      POLYGON ((394208.1309668442 4296804.617762511,...
# 1      POLYGON ((399776.4066106104 4299391.885758009,...
# 2      POLYGON ((395684.3247016144 4297527.500254651,...
# 3      POLYGON ((399263.2164539802 4309896.543402536,...
# 4      POLYGON ((394490.6016695436 4310216.892897176,...
# 5      POLYGON ((396502.8894078943 4286977.182923746,...
# 6      POLYGON ((399046.2454958253 4300214.602257961,...
# 7      POLYGON ((386089.3949611925 4301086.839064332,...
# 8      POLYGON ((389102.0881091862 4299160.50710729, ...
# 9      POLYGON ((388620.9666635342 4299439.190525914,...
# 10     POLYGON ((385254.464348799 4296914.168361772, ...
# 11     POLYGON ((362523.7384195475 4293450.381300154,...
# 12     POLYGON ((386369.4324261311 4271348.131204242,...
# 13     POLYGON ((381402.385145174 4271624.450243692, ...
# 14     POLYGON ((382178.9113882028 4281701.09783803, ...
# 15     POLYGON ((384712.3228142892 4311125.195170964,...
# 16     POLYGON ((384692.8217312816 4310893.82303577, ...
# 17     POLYGON ((389841.099531222 4272857.992894941, ...
# 18     POLYGON ((372836.5717400786 4292381.151540875,...
# 19     POLYGON ((373882.7995399676 4302186.385158389,...
# 20     POLYGON ((383297.110262957 4311139.428799067, ...
# 21     POLYGON ((384499.3840977545 4308613.604803124,...
# 22     POLYGON ((391604.8213873622 4310395.145925383,...
# 23     POLYGON ((383859.8726754758 4301265.386880544,...
# 24     POLYGON ((371120.2962601723 4292551.551853362,...
# 25     POLYGON ((348448.7700850833 4422380.390186925,...
# 26     POLYGON ((348448.7700850833 4422380.390186925,...
# 27     POLYGON ((348448.7700850833 4422380.390186925,...
# 28     POLYGON ((349024.3378084863 4422041.381468946,...
# 29     POLYGON ((350657.6518724022 4422082.013066452,...
# ...                                                  ...
# 10562                                               None
# 10563                                               None
# 10564                                               None
# 10565                                               None
# 10566                                               None
# 10567                                               None
# 10568                                               None
# 10569                                               None
# 10570                                               None
# 10571                                               None
# 10572                                               None
# 10573                                               None
# 10574                                               None
# 10575                                               None
# 10576                                               None
# 10577                                               None
# 10578                                               None
# 10579                                               None
# 10580                                               None
# 10581                                               None
# 10582                                               None
# 10583                                               None
# 10584                                               None
# 10585                                               None
# 10586                                               None
# 10587                                               None
# 10588                                               None
# 10589                                               None
# 10590                                               None
# 10591                                               None
#
# [10592 rows x 39 columns]

# %%
ptest_df=prec_df[prec_df.PRECINCT_e=='WOOSTER TWP 3']

# %%
ptest_df.plot()

# %%
map_df = map_df[map_df.geometry.notnull()]
prec_df = prec_df[prec_df.geometry.notnull()]

# %%
#prec_df=prec_df.to_crs(map_df.crs)
map_df=map_df.to_crs(prec_df.crs)

# %%
base = test_df.plot(color='white',edgecolor='black')
ptest_df.plot(ax=base, color='blue', figsize=(12, 12))
plt.savefig('District_1.png')
